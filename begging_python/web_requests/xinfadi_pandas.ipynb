# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

xinfadi_pd = pd.read_pickle('xinfadi.pkl')
avg = xinfadi_pd[xinfadi_pd['品名'] == '耙耙柑（丑橘）']['平均价']
avg = avg.sort_index()

plt.rcParams['font.sans-serif']=['SimHei']
fig = plt.figure()
fig.set_figwidth(20)
plt.xlabel('发布时间')
plt.ylabel('耙耙柑（丑橘）-平均价')
avg = avg.sort_index()
avg= avg['2021']
plt.plot(avg.index, avg)
avg
# Out:
# 发布日期
# 2021-08-31    2.8
# 2021-09-01    2.8
# 2021-09-02    2.8
# 2021-09-03    2.8
# 2021-09-04    2.8
#              ...
# 2021-12-27    5.0
# 2021-12-28    5.0
# 2021-12-29    5.0
# 2021-12-30    5.5
# 2021-12-31    5.5
# Name: 平均价, Length: 123, dtype: object
